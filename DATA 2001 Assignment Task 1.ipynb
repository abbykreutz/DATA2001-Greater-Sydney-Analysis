# %% [markdown]
# ## Importing Data Packages

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import json
from sqlalchemy import create_engine, MetaData
from sqlalchemy import Table, Column, Float, String
from sqlalchemy.sql import text
# do we need the from lines above except for sqlalchemy import create_engine?

# %% [markdown]
# ## Setting Up Database Connection

# %%
# Define database connection parameters. 
# credentials = 'Credentials.json'
username = 'postgres'
password = 'Gumba11$'
host = 'localhost'
port = '5432'
database = 'project'

# %%
# Create connection URL
engine_url = f'postgresql://{username}:{password}@{host}:{port}/{database}'
#Establish database connection
engine = create_engine(engine_url)

# %%
schema = 'public'
table_names = {
    'Businesses': 'businesses',
    'Stops': 'stops',
    'Polls': 'polls',
    'Schools': 'schools',
    'Population': 'population',
    'Income': 'income'
}

# %%
metadata = MetaData(schema=schema)
metadata.bind = engine

# %% [markdown]
# ## Importing Datasets

# %%
import os
cwd = os.getcwd()
print("Current working directory:", cwd)
# Out:
# Current working directory: /Users/abbykreutz/Desktop/DATA2001/Greater Sydney Analysis Assignment

# %% [markdown]
# ### Businesses.csv

# %%
# Import Businesses dataset
businesses_rawdf = pd.read_csv('Businesses.csv')
# Prepare a working copy
businesses_df = businesses_rawdf.copy()
businesses_df.to_sql(table_names['Businesses'], engine, schema=schema, if_exists='replace', index=False)
# Out:
# 217

# %%
# businesses_df = businesses_df[['industry_code', 'industry_name', 'sa2_code', 'sa2_name', '0_to_50k_businesses', '50k_to_200k_businesses', '200k_to_2m_businesses', '2m_to_5m_businesses', '5m_to_10m_businesses', '10m_or_more_businesses', 'total_businesses']]
len(businesses_df)
# Out:
# 12217

# %%
# Import Polls dataset
polls_rawdf = pd.read_csv('PollingPlaces2019.csv')
polls_df = polls_rawdf.copy()
polls_df.to_sql(table_names['Polls'], engine, schema=schema, if_exists='replace', index=False)
polls_df.head(10)
# Out:
#                                                  FID state  division_id  \
# 0  aec_federal_election_polling_places_2019.fid-4...   NSW          104
# 1  aec_federal_election_polling_places_2019.fid-4...   NSW          105
# 2  aec_federal_election_polling_places_2019.fid-4...   NSW          107
# 3  aec_federal_election_polling_places_2019.fid-4...   NSW          109
# 4  aec_federal_election_polling_places_2019.fid-4...   NSW          113
# 5  aec_federal_election_polling_places_2019.fid-4...   NSW          121
# 6  aec_federal_election_polling_places_2019.fid-4...   NSW          126
# 7  aec_federal_election_polling_places_2019.fid-4...   NSW          127
# 8  aec_federal_election_polling_places_2019.fid-4...   NSW          249
# 9  aec_federal_election_polling_places_2019.fid-4...   NSW          144
#
#      division_name  polling_place_id  polling_place_type_id  \
# 0           Barton             33595                      2
# 1        Bennelong             33596                      2
# 2         Blaxland             33600                      2
# 3           Calare             33603                      2
# 4           Cowper             33716                      2
# 5        Grayndler             33623                      2
# 6           Hunter             33627                      2
# 7  Kingsford Smith             33629                      2
# 8         Paterson             33628                      2
# 9             Reid             33638                      2
#
#         polling_place_name   premises_name premises_address_1  \
# 0  Special Hospital Team 1  Multiple sites                NaN
# 1  Special Hospital Team 1  Multiple sites                NaN
# 2  Special Hospital Team 1  Multiple sites                NaN
# 3  Special Hospital Team 1  Multiple sites                NaN
# 4  Special Hospital Team 2  Multiple sites                NaN
# 5  Special Hospital Team 1  Multiple sites                NaN
# 6  Special Hospital Team 1  Multiple sites                NaN
# 7  Special Hospital Team 1  Multiple sites                NaN
# 8  Special Hospital Team 1  Multiple sites                NaN
# 9  Special Hospital Team 1  Multiple sites                NaN
#
#   premises_address_2 premises_address_3 premises_suburb  \
# 0                NaN                NaN             NaN
# 1                NaN                NaN             NaN
# 2                NaN                NaN             NaN
# 3                NaN                NaN          ORANGE
# 4                NaN                NaN             NaN
# 5                NaN                NaN             NaN
# 6                NaN                NaN             NaN
# 7                NaN                NaN             NaN
# 8                NaN                NaN             NaN
# 9                NaN                NaN             NaN
#
#   premises_state_abbreviation  premises_post_code  latitude  longitude  \
# 0                         NSW                 NaN       NaN        NaN
# 1                         NSW                 NaN       NaN        NaN
# 2                         NSW                 NaN       NaN        NaN
# 3                         NSW              2800.0       NaN        NaN
# 4                         NSW                 NaN       NaN        NaN
# 5                         NSW                 NaN       NaN        NaN
# 6                         NSW                 NaN       NaN        NaN
# 7                         NSW                 NaN       NaN        NaN
# 8                         NSW                 NaN       NaN        NaN
# 9                         NSW                 NaN       NaN        NaN
#
#   the_geom
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN

# %%
# Import Stops dataset
stops_rawdf = pd.read_csv('Stops.txt', delimiter=',')
stops_df = stops_rawdf.copy()
stops_df.to_sql(table_names['Stops'], engine, schema=schema, if_exists='replace', index=False)
len(stops_df)
# Out:
# 114718

# %%
# Import Population dataset
population_rawdf = pd.read_csv('Population.csv')
population_df = population_rawdf.copy()
population_df.to_sql(table_names['Population'], engine, schema=schema, if_exists='replace', index=False)
population_df.head(10)
# Out:
#     sa2_code                     sa2_name  0-4_people  5-9_people  \
# 0  102011028     Avoca Beach - Copacabana         424         522
# 1  102011029  Box Head - MacMasters Beach         511         666
# 2  102011030              Calga - Kulnura         200         225
# 3  102011031          Erina - Green Point         683         804
# 4  102011032        Gosford - Springfield        1164        1044
# 5  102011033                      Kariong         433         510
# 6  102011034  Kincumber - Picketts Valley         430         434
# 7  102011035                       Narara         472         518
# 8  102011036       Niagara Park - Lisarow         461         589
# 9  102011037      Point Clare - Koolewong         356         411
#
#    10-14_people  15-19_people  20-24_people  25-29_people  30-34_people  \
# 0           623           552           386           222           306
# 1           702           592           461           347           420
# 2           258           278           274           227           214
# 3           880           838           661           502           587
# 4          1084          1072          1499          1864          1750
# 5           512           525           407           411           356
# 6           491           423           342           313           419
# 7           535           441           373           420           457
# 8           656           592           463           400           494
# 9           389           355           300           251           358
#
#    35-39_people  ...  45-49_people  50-54_people  55-59_people  60-64_people  \
# 0           416  ...           572           602           570           520
# 1           535  ...           749           749           794           895
# 2           286  ...           325           436           422           397
# 3           757  ...           859           882           901           930
# 4          1520  ...          1330          1241          1377          1285
# 5           441  ...           491           481           435           365
# 6           394  ...           419           415           422           459
# 7           522  ...           505           474           461           457
# 8           514  ...           581           567           572           498
# 9           423  ...           493           427           480           443
#
#    65-69_people  70-74_people  75-79_people  80-84_people  85-and-over_people  \
# 0           464           369           226           142                  70
# 1           863           925           603           331                 264
# 2           327           264           190           100                  75
# 3           917          1065           976           773                1028
# 4          1166           949           664           476                 537
# 5           241           157            97            90                  65
# 6           441           468           455           383                 523
# 7           367           322           201            95                  80
# 8           392           347           212           161                 189
# 9           346           367           300           241                 241
#
#    total_people
# 0          7530
# 1         11052
# 2          4748
# 3         14803
# 4         21346
# 5          6518
# 6          7628
# 7          7191
# 8          8237
# 9          6575
#
# [10 rows x 21 columns]

# %%
# Import Income dataset
income_rawdf = pd.read_csv('Income.csv')
income_df = income_rawdf.copy()
income_df.to_sql(table_names['Income'], engine, schema=schema, if_exists='replace', index=False)
# Out:
# 642

# %%
import geopandas as gpd
from sqlalchemy import text

# %%
from sqlalchemy.exc import SQLAlchemyError

create_postgis_extension = "CREATE EXTENSION IF NOT EXISTS postgis;"
enable_postgis_extension = "CREATE EXTENSION IF NOT EXISTS postgis_topology;"

with engine.connect() as connection:
        connection.execute(text(create_postgis_extension))
        connection.execute(text(enable_postgis_extension))
        connection.commit()

# %%
sa2_regions_path = 'SA2_2021_AUST_SHP_GDA2020/SA2_2021_AUST_GDA2020.shp'
sa2_regions_gdf = gpd.read_file(sa2_regions_path)
sa2_regions_gdf.to_postgis(name='sa2_regions', con=engine, if_exists='replace')

# %%
unique_constraint_query = """
ALTER TABLE sa2_regions
ADD CONSTRAINT unique_sa2_code21 UNIQUE ("SA2_CODE21");
"""

with engine.connect() as connection:
        connection.execute(text(unique_constraint_query))
        connection.commit()

# %%
future_df = gpd.read_file('catchments/catchments_future.shp')
primary_df = gpd.read_file('catchments/catchments_primary.shp')
secondary_df = gpd.read_file('catchments/catchments_secondary.shp')

# %%
concatenated_df = gpd.GeoDataFrame(pd.concat([future_df, primary_df, secondary_df], ignore_index=True))
concatenated_df.to_postgis('schools', engine, if_exists='replace', index=True, index_label='Index')

# %%
alter_queries = [
    "ALTER TABLE population ALTER COLUMN sa2_code TYPE TEXT;",
    "ALTER TABLE businesses ALTER COLUMN sa2_code TYPE TEXT;",
    "ALTER TABLE income ALTER COLUMN sa2_code21 TYPE TEXT;",
]

with engine.connect() as connection:
    for query in alter_queries:
        connection.execute(text(query))
    connection.commit()

# %%
primary_key_constraints = {
    'Stops': 'stop_id',
    'Polls': 'FID',
    'Population': 'sa2_code',
    'Income': 'sa2_code21',
    'Schools': 'Index',
}

# %%
# Apply Primary Key Constraints
for table_name, primary_key_column in primary_key_constraints.items():
    with engine.connect() as connection:
        primary_key_query = f'ALTER TABLE "{schema}"."{table_names[table_name]}" ADD PRIMARY KEY ("{primary_key_column}");'
        connection.execute(text(primary_key_query))
        connection.commit()

# %%
query = "ALTER TABLE businesses ADD CONSTRAINT pk_businesses PRIMARY KEY (industry_code, sa2_code);"

with engine.connect() as connection:
    connection.execute(text(query))
    connection.commit()

# %%
query = 'ALTER TABLE sa2_regions ADD PRIMARY KEY ("SA2_CODE21");'

with engine.connect() as connection:
    connection.execute(text(query))
    connection.commit()

# %%
foreign_key_constraints = {
    'Population': {'sa2_code': 'VARCHAR'},
    'Income': {'sa2_code21': 'VARCHAR'},
    'Businesses': {'sa2_code': 'VARCHAR'}
}

# %%
# Apply Foreign Key Constraints
for table_name, columns in foreign_key_constraints.items():
    for column_name, data_type in columns.items():
        if table_name in ['Stops', 'Polling']:
            referenced_column = 'geometry'
        else:
            referenced_column = 'SA2_CODE21'
        
        alter_query = f'ALTER TABLE "{schema}"."{table_names[table_name]}" ' \
                      f'ADD CONSTRAINT fk_{table_name}_{column_name} ' \
                      f'FOREIGN KEY ("{column_name}") ' \
                      f'REFERENCES "{schema}".sa2_regions ("{referenced_column}");'
        
        with engine.connect() as connection:
            connection.execute(text(alter_query))
            connection.commit()

# %%
query = """
ALTER TABLE polls
ADD COLUMN sa2_code TEXT;

UPDATE polls
SET sa2_code = sa2_regions."SA2_CODE21"
FROM sa2_regions
WHERE ST_Contains(sa2_regions.geometry, ST_SetSRID(ST_MakePoint(polls.longitude, polls.latitude), 7844));

ALTER TABLE polls
ADD CONSTRAINT fk_sa2_code
FOREIGN KEY (sa2_code)
REFERENCES sa2_regions ("SA2_CODE21");
"""

with engine.connect() as connection:
    connection.execute(text(query))
    connection.commit()

# %%
query = """
ALTER TABLE stops
ADD COLUMN sa2_code TEXT;

UPDATE stops
SET sa2_code = sa2_regions."SA2_CODE21"
FROM sa2_regions
WHERE ST_Contains(sa2_regions.geometry, ST_SetSRID(ST_MakePoint(stops.stop_lon, stops.stop_lat), 7844));

ALTER TABLE stops
ADD CONSTRAINT fk_sa2_code
FOREIGN KEY (sa2_code)
REFERENCES sa2_regions ("SA2_CODE21");
"""

with engine.connect() as connection:
    connection.execute(text(query))
    connection.commit()

# %%
query = """
ALTER TABLE schools
ADD COLUMN geom_transformed GEOMETRY;

UPDATE schools
SET geom_transformed = ST_Transform(geometry, 7844);

ALTER TABLE schools
ADD COLUMN sa2_code TEXT;

UPDATE schools
SET sa2_code = UPPER(sa2_regions."SA2_CODE21")
FROM sa2_regions
WHERE ST_Intersects(schools.geom_transformed, sa2_regions.geometry);

ALTER TABLE schools
ADD CONSTRAINT fk_sa2_code
FOREIGN KEY (sa2_code)
REFERENCES sa2_regions ("SA2_CODE21");
"""

with engine.connect() as connection:
    connection.execute(text(query))
    connection.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 22
#       1 query = """
#       2 ALTER TABLE schools
#       3 ADD COLUMN geom_transformed GEOMETRY;
#    (...)
#      19 REFERENCES sa2_regions ("SA2_CODE21");
#      20 """
# ---> 22 with engine.connect() as connection:
#      23     connection.execute(text(query))
#      24     connection.commit()
#
# NameError: name 'engine' is not defined

# %%
metadata.create_all(bind=engine)

# %%
print("done")
# Out:
# done
